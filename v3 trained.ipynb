# %% [markdown]
# # 02 · SGD vs APGD-SGD — Complex-Weight CVNN (v5)
#
# Model: 1.24M complex params, stride-based downsampling.
# Optimizer: v8 pure Armijo, eval() mode, Wirtinger gradients.

# %%
import os, sys, shutil

# ── Copy source files from dataset to /kaggle/working ─────────────────────────
# This ensures we always use the exact versions in the dataset,
# with no caching issues (copies happen fresh every kernel restart).
DATASET_DIR = "/kaggle/input/datasets/hardikgogia/apgd-2"

for fname in ["cvnn_model.py", "optimizers_v8.py"]:
    src = os.path.join(DATASET_DIR, fname)
    dst = os.path.join("/kaggle/working", fname)
    shutil.copy2(src, dst)
    print(f"Copied {fname}  ({os.path.getsize(dst):,} bytes)")

print("Done.")
# Out:
# Copied cvnn_model.py  (12,509 bytes)
# Copied optimizers_v8.py  (18,248 bytes)
# Done.

# %%
# %matplotlib inline
import sys, os, itertools, copy, gc
sys.path.insert(0, '/kaggle/working')           # our files (cvnn_model, optimizers_v7)
sys.path.insert(1, '/kaggle/input/datasets/hardikgogia/apgd-2') # dataset files (merged_train.pt etc)

import torch
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from torch.utils.data import DataLoader
import torch.nn as nn
from sklearn.metrics import (
    confusion_matrix, classification_report, ConfusionMatrixDisplay
)

from cvnn_model      import CV_CNN
from optimizers_v8   import ComplexSGD, APGD_SGD
from dataset         import load_merged_dataset

torch.manual_seed(42)
np.random.seed(42)

# Sanity check: confirm we loaded the right files
m = CV_CNN(num_classes=10)
p = m.count_parameters()
print(f"Model: {p['complex_params']:,} complex params ({p['real_equivalent_params']:,} real-equiv)")
assert p['complex_params'] == 1_244_042, f"Wrong model loaded! Got {p['complex_params']}"
print("Model v5 confirmed.")
del m
# Out:
# Model: 1,244,042 complex params (2,488,084 real-equiv)
# Model v5 confirmed.

# %%
# ── Constants ─────────────────────────────────────────────────────────────────
DATA_DIR   = "/kaggle/input/datasets/hardikgogia/apgd-2"
BATCH_SIZE = 64
EPOCHS     = 300
DEVICE     = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device : {DEVICE}")

# ── Data loaders ──────────────────────────────────────────────────────────────
train_ds     = load_merged_dataset(os.path.join(DATA_DIR, "merged_train.pt"))
test_ds      = load_merged_dataset(os.path.join(DATA_DIR, "merged_test.pt"))
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=0, pin_memory=False)
val_loader   = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=0, pin_memory=False)
NUM_CLASSES  = train_ds.num_classes
print(f"Classes: {NUM_CLASSES}  |  Train: {len(train_ds)}  |  Val: {len(test_ds)}")

try:
    CLASS_NAMES = train_ds.class_names
except AttributeError:
    CLASS_NAMES = [str(i) for i in range(NUM_CLASSES)]
print(f"Classes: {CLASS_NAMES}")

torch.backends.cudnn.benchmark = True
CKPT_DIR = "/kaggle/working/checkpoints"
SAVE_DIR  = "/kaggle/working/plots/sgd"
os.makedirs(CKPT_DIR, exist_ok=True)
os.makedirs(SAVE_DIR,  exist_ok=True)
print(f"Checkpoint dir : {CKPT_DIR}")
print(f"Save dir       : {SAVE_DIR}")
# Out:
# Device : cuda
# Classes: 10  |  Train: 6549  |  Val: 2596
# Classes: ['bmp2_tank', 'btr70_transport', 't72_tank', 'd7_bulldozer', 't62_tank', 'zil131_truck', 'btr60_transport', 'zsu23-4_gun', 'brdm2_truck', '2s1_gun']
# Checkpoint dir : /kaggle/working/checkpoints
# Save dir       : /kaggle/working/plots/sgd

# %%
# ── APGD hyper-parameters (v8) ────────────────────────────────────────────────
STATIC_LR        = 0.03
SADDLE_BT_THRESH = 2
ALPHA_ARMIJO     = 0.05
BETA_BT          = 0.5
K_PHASES         = 17
MAX_BT           = 15
CLIP             = 2.0
print(f"APGD config: lr={STATIC_LR}  saddle_bt_thresh={SADDLE_BT_THRESH}  K={K_PHASES}  alpha={ALPHA_ARMIJO}")
# Out:
# APGD config: lr=0.03  saddle_bt_thresh=2  K=17  alpha=0.05

# %%
def train_static(model, loader, optimizer, criterion, clip=2.0):
    model.train()
    total = 0.0
    for x, y in loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        optimizer.zero_grad()
        loss = criterion(model(x), y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()
        total += loss.item()
    return total / len(loader)


def train_apgd(model, loader, optimizer_apgd, criterion):
    model.train()
    tot_loss, tot_theta, tot_gamma, n_saddle = 0.0, 0.0, 0.0, 0
    for x, y in loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        loss, theta, gamma, regime = optimizer_apgd.step(x, y, criterion)
        tot_loss  += loss
        tot_theta += theta
        tot_gamma += gamma
        if regime == 'saddle':
            n_saddle += 1
    n = len(loader)
    return tot_loss/n, tot_theta/n, tot_gamma/n, n_saddle


@torch.no_grad()
def evaluate(model, loader, criterion):
    """Fast per-epoch evaluation — returns (loss, accuracy)."""
    model.eval()
    tot_loss, correct, total = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        out       = model(x)
        tot_loss += criterion(out, y).item()
        correct  += (out.argmax(1) == y).sum().item()
        total    += y.size(0)
    return tot_loss / len(loader), correct / total

# %%
# ── Full test evaluation ───────────────────────────────────────────────────────

@torch.no_grad()
def evaluate_full(model, loader, criterion, class_names=None):
    """
    Full evaluation pass.  Returns a dict with:
      loss, accuracy, per_class_acc, confusion matrix, preds, labels.
    """
    model.eval()
    tot_loss, correct, total = 0.0, 0, 0
    all_preds, all_labels = [], []
    for x, y in loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        out       = model(x)
        tot_loss += criterion(out, y).item()
        preds     = out.argmax(1)
        correct  += (preds == y).sum().item()
        total    += y.size(0)
        all_preds.extend(preds.cpu().tolist())
        all_labels.extend(y.cpu().tolist())

    n_classes = len(set(all_labels))
    names     = class_names or [str(i) for i in range(n_classes)]
    cm        = confusion_matrix(all_labels, all_preds, labels=list(range(n_classes)))
    per_class_acc = cm.diagonal() / cm.sum(axis=1).clip(min=1)

    return {
        'loss':          tot_loss / len(loader),
        'accuracy':      correct / total,
        'per_class_acc': per_class_acc,
        'cm':            cm,
        'preds':         all_preds,
        'labels':        all_labels,
        'class_names':   names,
    }


def print_test_report(results, title):
    """Prints overall accuracy, per-class bar table, and sklearn report."""
    names = results['class_names']
    print(f"\n{'═'*62}")
    print(f"  TEST REPORT — {title}")
    print(f"{'═'*62}")
    print(f"  Overall accuracy : {results['accuracy']*100:.2f}%")
    print(f"  Test loss        : {results['loss']:.4f}")
    print(f"\n  Per-class accuracy:")
    print(f"  {'Class':<20} {'Acc':>8}  {'N':>6}")
    print(f"  {'─'*40}")
    cm = results['cm']
    for i, (name, acc) in enumerate(zip(names, results['per_class_acc'])):
        n   = cm[i].sum()
        bar = '█' * int(acc * 20)
        print(f"  {name:<20} {acc*100:>7.2f}%  {n:>6d}  {bar}")
    print(f"\n  Classification report:")
    print(classification_report(
        results['labels'], results['preds'],
        target_names=names, digits=4))


def plot_confusion_matrix(results, title, save_dir, filename):
    """Side-by-side normalised and raw confusion matrices."""
    os.makedirs(save_dir, exist_ok=True)
    names = results['class_names']
    cm    = results['cm']
    cm_n  = cm.astype(float) / cm.sum(axis=1, keepdims=True).clip(min=1)

    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    fig.suptitle(f"Confusion Matrix — {title}", fontsize=13, fontweight='bold')
    for ax, data, fmt, subtitle in zip(
            axes,
            [cm_n,    cm],
            ['.2f',   'd'],
            ['Normalised (row %)', 'Raw counts']):
        disp = ConfusionMatrixDisplay(confusion_matrix=data, display_labels=names)
        disp.plot(ax=ax, colorbar=True, cmap='Blues',
                  values_format=fmt, xticks_rotation=45)
        ax.set_title(subtitle, fontsize=11)
        ax.set_xlabel('Predicted', fontsize=9)
        ax.set_ylabel('True',      fontsize=9)
    plt.tight_layout()
    fname = os.path.join(save_dir, filename)
    plt.savefig(fname, dpi=150, bbox_inches='tight')
    plt.show()
    plt.close('all')  # ── memory: release figure after display ──────────────
    print(f"Saved → {fname}")


def plot_per_class_bar(results_static, results_apgd, save_dir):
    """Side-by-side per-class accuracy bar chart comparing both optimisers."""
    names = results_static['class_names']
    x     = np.arange(len(names))
    w     = 0.35

    fig, ax = plt.subplots(figsize=(14, 5))
    b1 = ax.bar(x - w/2, results_static['per_class_acc'] * 100,
                w, label='Static SGD θ=0', color='steelblue',  alpha=0.85)
    b2 = ax.bar(x + w/2, results_apgd['per_class_acc']   * 100,
                w, label='APGD-SGD',       color='darkorange', alpha=0.85)

    ax.axhline(results_static['accuracy'] * 100, color='steelblue',
               ls='--', lw=1.2, label=f"Static overall ({results_static['accuracy']*100:.1f}%)")
    ax.axhline(results_apgd['accuracy']   * 100, color='darkorange',
               ls='--', lw=1.2, label=f"APGD overall   ({results_apgd['accuracy']*100:.1f}%)")

    ax.set_xlabel('Class'); ax.set_ylabel('Accuracy (%)')
    ax.set_title('Per-Class Test Accuracy: Static SGD vs APGD-SGD')
    ax.set_xticks(x); ax.set_xticklabels(names, rotation=30, ha='right')
    ax.set_ylim(0, 108); ax.legend(fontsize=9); ax.grid(axis='y', alpha=0.3)

    for bar in itertools.chain(b1, b2):
        h = bar.get_height()
        ax.annotate(f'{h:.1f}', xy=(bar.get_x() + bar.get_width()/2, h),
                    xytext=(0, 2), textcoords='offset points',
                    ha='center', va='bottom', fontsize=7)
    plt.tight_layout()
    fname = os.path.join(save_dir, 'SGD_per_class_acc.png')
    plt.savefig(fname, dpi=150, bbox_inches='tight')
    plt.show()
    plt.close('all')  # ── memory: release figure after display ──────────────
    print(f"Saved → {fname}")

# %%
# ── Training curve plots ───────────────────────────────────────────────────────

def plot_static_vs_apgd(static_hist, apgd_hist, title, save_dir):
    """
    5-panel figure:
      [0] Validation loss   [1] Train loss   [2] Validation accuracy
      [3] APGD: avg‖g‖ (raw) + saddle count per epoch
      [4] APGD: avg θ per epoch
    """
    os.makedirs(save_dir, exist_ok=True)
    ep  = range(1, len(static_hist['val_loss']) + 1)
    fig, axes = plt.subplots(1, 5, figsize=(25, 4))
    fig.suptitle(title, fontsize=13, fontweight='bold')

    # ── [0] Validation loss ──────────────────────────────────────────────────
    axes[0].plot(ep, static_hist['val_loss'], label='Static θ=0', lw=2, color='steelblue')
    axes[0].plot(ep, apgd_hist['val_loss'],   label='APGD',       lw=2, color='darkorange', ls='--')
    axes[0].set_title('Validation Loss'); axes[0].set_xlabel('Epoch')
    axes[0].legend(); axes[0].grid(True, alpha=0.3)

    # ── [1] Train loss ───────────────────────────────────────────────────────
    axes[1].plot(ep, static_hist['train_loss'], label='Static θ=0', lw=2, color='steelblue')
    axes[1].plot(ep, apgd_hist['train_loss'],   label='APGD',       lw=2, color='darkorange', ls='--')
    axes[1].set_title('Train Loss'); axes[1].set_xlabel('Epoch')
    axes[1].legend(); axes[1].grid(True, alpha=0.3)

    # ── [2] Validation accuracy ──────────────────────────────────────────────
    axes[2].plot(ep, [a * 100 for a in static_hist['val_acc']],
                 label='Static θ=0', lw=2, color='steelblue')
    axes[2].plot(ep, [a * 100 for a in apgd_hist['val_acc']],
                 label='APGD',       lw=2, color='darkorange', ls='--')
    # Mark best val accuracy for each
    best_s_ep  = int(np.argmax(static_hist['val_acc'])) + 1
    best_s_acc = max(static_hist['val_acc']) * 100
    best_a_ep  = int(np.argmax(apgd_hist['val_acc'])) + 1
    best_a_acc = max(apgd_hist['val_acc']) * 100
    axes[2].scatter([best_s_ep], [best_s_acc], s=60, color='steelblue',  zorder=5)
    axes[2].scatter([best_a_ep], [best_a_acc], s=60, color='darkorange', zorder=5)
    axes[2].annotate(f'{best_s_acc:.1f}%', (best_s_ep, best_s_acc),
                     textcoords='offset points', xytext=(4, -10), fontsize=7, color='steelblue')
    axes[2].annotate(f'{best_a_acc:.1f}%', (best_a_ep, best_a_acc),
                     textcoords='offset points', xytext=(4,   4), fontsize=7, color='darkorange')
    axes[2].set_title('Validation Accuracy (%)'); axes[2].set_xlabel('Epoch')
    axes[2].set_ylim(0, 105); axes[2].legend(); axes[2].grid(True, alpha=0.3)
    axes[2].yaxis.set_major_formatter(mticker.FormatStrFormatter('%.0f%%'))

    # ── [3] APGD: raw ‖g‖ (avg per epoch) + saddle count ────────────────────
    # gamma is now raw ‖g‖ (not ‖g‖/L̂) — label accordingly
    c_g, c_s = 'steelblue', 'crimson'
    ax3  = axes[3]
    ax3b = ax3.twinx()
    ax3.plot(ep, apgd_hist['gammas'],
             color=c_g, lw=1.5, label='avg ‖g‖ (raw)')
    ax3b.bar(ep, apgd_hist['saddle_counts'],
             color=c_s, alpha=0.35, width=1.0, label='saddle escapes / epoch')
    ax3.set_title('APGD: Gradient Norm & Saddle Escapes')
    ax3.set_xlabel('Epoch')
    ax3.set_ylabel('avg ‖g‖', color=c_g);         ax3.tick_params(axis='y', labelcolor=c_g)
    ax3b.set_ylabel('saddle escapes',  color=c_s); ax3b.tick_params(axis='y', labelcolor=c_s)
    lines  = ax3.get_legend_handles_labels()[0]  + ax3b.get_legend_handles_labels()[0]
    labels = ax3.get_legend_handles_labels()[1]  + ax3b.get_legend_handles_labels()[1]
    ax3.legend(lines, labels, fontsize=7); ax3.grid(True, alpha=0.3)

    # ── [4] APGD: avg selected θ per epoch ──────────────────────────────────
    ax4 = axes[4]
    ax4.plot(ep, np.degrees(apgd_hist['thetas']),
             color='purple', lw=1.5, label='avg θ* (°)')
    ax4.axhline(0, color='grey', ls='--', lw=0.8)
    ax4.fill_between(ep, np.degrees(apgd_hist['thetas']), 0,
                     alpha=0.12, color='purple')
    ax4.set_title('APGD: Avg Selected Phase θ*')
    ax4.set_xlabel('Epoch'); ax4.set_ylabel('θ* (degrees)')
    ax4.legend(fontsize=7); ax4.grid(True, alpha=0.3)

    plt.tight_layout()
    fname = os.path.join(save_dir, f"{title.replace(' ', '_')}_static_vs_apgd.png")
    plt.savefig(fname, dpi=150, bbox_inches='tight')
    plt.show()
    plt.close('all')  # ── memory: release figure after display ──────────────
    print(f"Saved → {fname}")


def summary_table(static_hist, apgd_hist, label):
    print(f"\n{'─'*64}")
    print(f"  {label}")
    print(f"{'─'*64}")
    print(f"  {'Strategy':<14} {'Best Val Loss':>14} {'Best Val Acc':>13} {'Final Acc':>10} {'@ Epoch':>9}")
    print(f"  {'─'*60}")
    for name, h in [('Static θ=0', static_hist), ('APGD-SGD', apgd_hist)]:
        ba   = max(h['val_acc'])
        bl   = min(h['val_loss'])
        fa   = h['val_acc'][-1]
        ep_b = h['val_acc'].index(ba) + 1
        print(f"  {name:<14} {bl:>14.4f} {ba:>12.4f} {fa:>10.4f} {ep_b:>9}")

# %%
SAVE_DIR  = "/kaggle/working/plots/sgd"
os.makedirs(SAVE_DIR, exist_ok=True)

model_s   = CV_CNN(num_classes=NUM_CLASSES).to(DEVICE)
opt_s     = ComplexSGD(model_s, lr=STATIC_LR, theta=0.0)
criterion = nn.CrossEntropyLoss()
hist_s    = {'train_loss': [], 'val_loss': [], 'val_acc': []}

# ── Capture initial state dict for matched initialization ──────────────────────
# Saved here so model_a can start from the exact same weights as model_s.
init_state_dict = copy.deepcopy(model_s.state_dict())

# ── Best-model tracking for Static SGD ────────────────────────────────────────
best_val_acc_s = 0.0

print(f"Static SGD  lr={STATIC_LR}  θ=0")
for epoch in range(1, EPOCHS + 1):
    tr     = train_static(model_s, train_loader, opt_s, criterion)
    vl, va = evaluate(model_s, val_loader, criterion)
    hist_s['train_loss'].append(tr)
    hist_s['val_loss'].append(vl)
    hist_s['val_acc'].append(va)
    if epoch % 10 == 0 or epoch == 1:
        print(f"  Ep {epoch:03d}  train={tr:.4f}  val={vl:.4f}  acc={va:.4f}")
    # ── Save best-model checkpoint ─────────────────────────────────────────────
    if va > best_val_acc_s:
        best_val_acc_s = va
        torch.save({
            'epoch':           epoch,
            'model_state_dict': model_s.state_dict(),
            'val_acc':         va,
            'val_loss':        vl,
            'train_loss':      tr,
            'hist':            hist_s,
        }, os.path.join(CKPT_DIR, "static_sgd_best.pt"))
    # ── Save periodic checkpoint every 50 epochs ───────────────────────────────
    if epoch % 50 == 0:
        torch.save({
            'epoch':           epoch,
            'model_state_dict': model_s.state_dict(),
            'hist':            hist_s,
        }, os.path.join(CKPT_DIR, f"static_sgd_ep{epoch:03d}.pt"))

    # In the SGD training loop, add after each epoch:
    t = epoch / EPOCHS
    cosine_factor = 0.5 * (1.0 + np.cos(np.pi * t))
    new_lr = 1e-4 + (STATIC_LR - 1e-4) * cosine_factor   # anneal to 1e-4
    opt_s.complex_lr = new_lr * np.exp(1j * 0.0)

print("Static SGD done.")

# ── Free GPU cache after run ───────────────────────────────────────────────────
torch.cuda.empty_cache()
gc.collect()
# Out:
# Static SGD  lr=0.03  θ=0
#   Ep 001  train=2.2410  val=2.2801  acc=0.1067
#   Ep 010  train=1.8211  val=2.0076  acc=0.2450
#   Ep 020  train=1.5799  val=1.8169  acc=0.3582
#   Ep 030  train=1.4768  val=1.5732  acc=0.4160
#   Ep 040  train=1.3983  val=1.7341  acc=0.4056
#   Ep 050  train=1.3361  val=1.4980  acc=0.4761
#   Ep 060  train=1.2749  val=1.3654  acc=0.5173
#   Ep 070  train=1.2033  val=1.4121  acc=0.5539
#   Ep 080  train=1.1157  val=1.5459  acc=0.4935
#   Ep 090  train=1.0089  val=1.4606  acc=0.5381
#   Ep 100  train=0.9279  val=1.2410  acc=0.6094
#   Ep 110  train=0.8381  val=0.9974  acc=0.6541
#   Ep 120  train=0.7600  val=0.9475  acc=0.6926
#   Ep 130  train=0.6923  val=1.0564  acc=0.7038
#   Ep 140  train=0.6223  val=0.8314  acc=0.7577
#   Ep 150  train=0.5759  val=0.9195  acc=0.6753
#   Ep 160  train=0.5227  val=0.6571  acc=0.7889
#   Ep 170  train=0.4838  val=0.9166  acc=0.7076
#   Ep 180  train=0.4522  val=0.6899  acc=0.7762
#   Ep 190  train=0.4264  val=0.5807  acc=0.8101
#   Ep 200  train=0.4015  val=0.6091  acc=0.7970
#   Ep 210  train=0.3921  val=0.5549  acc=0.8078
#   Ep 220  train=0.3631  val=0.6124  acc=0.7947
#   Ep 230  train=0.3560  val=0.7422  acc=0.7581
#   Ep 240  train=0.3392  val=0.6620  acc=0.7762
#   Ep 250  train=0.3287  val=0.5764  acc=0.8097
#   Ep 260  train=0.3299  val=0.5359  acc=0.8163
#   Ep 270  train=0.3155  val=0.5738  acc=0.8047
#   Ep 280  train=0.3151  val=0.5991  acc=0.8008
#   Ep 290  train=0.3204  val=0.5957  acc=0.7985
#   Ep 300  train=0.3107  val=0.5928  acc=0.8012
# Static SGD done.
# 414

# %%
# Load best checkpoint before evaluating SGD
ckpt_s = torch.load(os.path.join(CKPT_DIR, "static_sgd_best.pt"), map_location=DEVICE)
model_s.load_state_dict(ckpt_s['model_state_dict'])
print(f"SGD best: ep{ckpt_s['epoch']}  val_acc={ckpt_s['val_acc']:.4f}")
results_static = evaluate_full(model_s, val_loader, criterion, CLASS_NAMES)

# ── Static SGD — test evaluation ──────────────────────────────────────────────
results_static = evaluate_full(model_s, val_loader, criterion, CLASS_NAMES)
print_test_report(results_static, "Static SGD (θ=0)")
plot_confusion_matrix(results_static, "Static SGD (θ=0)",
                      SAVE_DIR, "SGD_static_confusion.png")
# Out:
# SGD best: ep183  val_acc=0.8236
#
# ══════════════════════════════════════════════════════════════
#   TEST REPORT — Static SGD (θ=0)
# ══════════════════════════════════════════════════════════════
#   Overall accuracy : 82.36%
#   Test loss        : 0.5530
#
#   Per-class accuracy:
#   Class                     Acc       N
#   ────────────────────────────────────────
#   bmp2_tank              79.56%     587  ███████████████
#   btr70_transport        46.43%     196  █████████
#   t72_tank               87.99%     583  █████████████████
#   d7_bulldozer           85.95%     121  █████████████████
#   t62_tank               94.40%     125  ██████████████████
#   zil131_truck           86.96%     115  █████████████████
#   btr60_transport        43.96%      91  ████████
#   zsu23-4_gun            97.83%     277  ███████████████████
#   brdm2_truck            88.04%     276  █████████████████
#   2s1_gun                84.89%     225  ████████████████
#
#   Classification report:
#                  precision    recall  f1-score   support
#
#       bmp2_tank     0.8491    0.7956    0.8215       587
# btr70_transport     0.8426    0.4643    0.5987       196
#        t72_tank     0.9260    0.8799    0.9024       583
#    d7_bulldozer     0.8889    0.8595    0.8739       121
#        t62_tank     0.7973    0.9440    0.8645       125
#    zil131_truck     0.9259    0.8696    0.8969       115
# btr60_transport     0.2326    0.4396    0.3042        91
#     zsu23-4_gun     0.8658    0.9783    0.9186       277
#     brdm2_truck     0.8741    0.8804    0.8773       276
#         2s1_gun     0.7702    0.8489    0.8076       225
#
#        accuracy                         0.8236      2596
#       macro avg     0.7972    0.7960    0.7865      2596
#    weighted avg     0.8446    0.8236    0.8276      2596
# Saved → /kaggle/working/plots/sgd/SGD_static_confusion.png

# %%
EPOCHS     = 350

model_a = CV_CNN(num_classes=NUM_CLASSES).to(DEVICE)

# ── Load same initialization as Static SGD for fair comparison ────────────────
# This ensures any accuracy gap is due to the optimizer, not initialization luck.
model_a.load_state_dict(copy.deepcopy(init_state_dict))

opt_a   = APGD_SGD(model_a,
                   base_lr         = STATIC_LR,
                   saddle_bt_thresh= SADDLE_BT_THRESH,
                   alpha           = ALPHA_ARMIJO,
                   beta            = BETA_BT,
                   K               = K_PHASES,
                   max_backtrack   = MAX_BT,
                   clip            = CLIP,
                   verbose         = 100)   # print every 100 batches (Kaggle output buffer)
hist_a  = {'train_loss': [], 'val_loss': [], 'val_acc': [],
           'thetas': [], 'gammas': [], 'saddle_counts': []}

# ── Best-model tracking for APGD-SGD ──────────────────────────────────────────
best_val_acc_a = 0.0

print(f"APGD-SGD  base_lr={STATIC_LR}  saddle_bt_thresh={SADDLE_BT_THRESH}  K={K_PHASES}")
for epoch in range(1, EPOCHS + 1):
    tr, avg_theta, avg_gamma, n_saddle = train_apgd(
        model_a, train_loader, opt_a, criterion)
    vl, va = evaluate(model_a, val_loader, criterion)
    hist_a['train_loss'].append(tr)
    hist_a['val_loss'].append(vl)
    hist_a['val_acc'].append(va)
    hist_a['thetas'].append(avg_theta)
    hist_a['gammas'].append(avg_gamma)
    hist_a['saddle_counts'].append(n_saddle)
    if epoch % 10 == 0 or epoch == 1:
        print(f"  Ep {epoch:03d}  train={tr:.4f}  val={vl:.4f}  acc={va:.4f}"
              f"  |  avg_θ={avg_theta:.3f}  avg_γ={avg_gamma:.3f}"
              f"  saddles={n_saddle}/{len(train_loader)}")
    # ── Save best-model checkpoint ─────────────────────────────────────────────
    if va > best_val_acc_a:
        best_val_acc_a = va
        torch.save({
            'epoch':           epoch,
            'model_state_dict': model_a.state_dict(),
            'val_acc':         va,
            'val_loss':        vl,
            'train_loss':      tr,
            'avg_theta':       avg_theta,
            'avg_gamma':       avg_gamma,
            'hist':            hist_a,
        }, os.path.join(CKPT_DIR, "apgd_sgd_best.pt"))
    # ── Save periodic checkpoint every 50 epochs ───────────────────────────────
    if epoch % 50 == 0:
        torch.save({
            'epoch':           epoch,
            'model_state_dict': model_a.state_dict(),
            'hist':            hist_a,
        }, os.path.join(CKPT_DIR, f"apgd_sgd_ep{epoch:03d}.pt"))
print("APGD-SGD done.")

# ── Free GPU cache after run ───────────────────────────────────────────────────
torch.cuda.empty_cache()
gc.collect()
# Out:
# APGD-SGD  base_lr=0.03  saddle_bt_thresh=2  K=17
#   [APGD step   100]  loss=2.2761  g_raw=0.649  g_clip=0.649  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 001  train=2.2399  val=2.2661  acc=0.1063  |  avg_θ=-0.004  avg_γ=0.457  saddles=2/103
#   [APGD step   200]  loss=2.1679  g_raw=0.520  g_clip=0.520  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step   300]  loss=2.0603  g_raw=0.627  g_clip=0.627  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step   400]  loss=2.2010  g_raw=0.465  g_clip=0.465  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step   500]  loss=2.1211  g_raw=0.623  g_clip=0.623  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step   600]  loss=2.1172  g_raw=1.048  g_clip=1.048  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step   700]  loss=2.1409  g_raw=1.227  g_clip=1.227  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step   800]  loss=1.9675  g_raw=1.443  g_clip=1.443  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step   900]  loss=1.7570  g_raw=3.234  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  1000]  loss=1.9014  g_raw=3.320  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 010  train=1.8569  val=1.8746  acc=0.3459  |  avg_θ=-0.006  avg_γ=3.747  saddles=14/103
#   [APGD step  1100]  loss=1.7450  g_raw=3.415  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  1200]  loss=1.6905  g_raw=4.692  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  1300]  loss=1.5386  g_raw=3.955  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=+0.589rad  rho=0.01500  bt1= 2
#              phase scan: -84°→1.5553   -79°→1.5472   -73°→1.5403   -67°→1.5345   -62°→1.5298   -56°→1.5261   -51°→1.5233   -45°→1.5213   -34°→1.5190   -23°→1.5181   -11°→1.5175   +0°→1.5166   +11°→1.5150   +23°→1.5132   +34°→1.5120★  +45°→1.5126   +51°→1.5139
#   [APGD step  1400]  loss=1.4360  g_raw=4.323  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  1500]  loss=1.6192  g_raw=4.480  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  1600]  loss=1.5177  g_raw=5.913  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  1700]  loss=1.4952  g_raw=3.491  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  1800]  loss=1.5299  g_raw=6.275  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  1900]  loss=1.6060  g_raw=6.297  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  2000]  loss=1.4976  g_raw=5.281  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 020  train=1.5654  val=1.6130  acc=0.4176  |  avg_θ=-0.008  avg_γ=5.295  saddles=10/103
#   [APGD step  2100]  loss=1.6356  g_raw=7.672  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  2200]  loss=1.6103  g_raw=7.919  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  2500]  loss=1.3768  g_raw=6.700  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  2600]  loss=1.6249  g_raw=7.980  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  2700]  loss=1.5710  g_raw=6.000  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  2800]  loss=1.3104  g_raw=3.604  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  2900]  loss=1.3145  g_raw=3.073  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  3000]  loss=1.5032  g_raw=6.841  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 030  train=1.4546  val=1.7364  acc=0.4126  |  avg_θ=-0.025  avg_γ=5.229  saddles=14/103
#   [APGD step  3100]  loss=1.3843  g_raw=6.773  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  3200]  loss=1.3572  g_raw=6.460  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  3300]  loss=1.5059  g_raw=4.658  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=+0.196rad  rho=0.01500  bt1= 2
#              phase scan: -84°→1.5010   -79°→1.4880   -73°→1.4764   -67°→1.4662   -62°→1.4574   -56°→1.4501   -51°→1.4440   -45°→1.4392   -34°→1.4326   -23°→1.4290   -11°→1.4274   +0°→1.4268   +11°→1.4268★  +23°→1.4277   +34°→1.4302   +45°→1.4358   +51°→1.4401
#   [APGD step  3400]  loss=1.4874  g_raw=3.404  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  3500]  loss=1.5820  g_raw=8.502  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  3600]  loss=1.5350  g_raw=8.763  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  3700]  loss=1.4100  g_raw=2.784  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  3800]  loss=1.6321  g_raw=6.474  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  3900]  loss=1.3475  g_raw=8.776  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  4000]  loss=1.2337  g_raw=3.474  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=+0.785rad  rho=0.03000  bt1= 1
#              phase scan: -84°→1.2272   -79°→1.2209   -73°→1.2154   -67°→1.2106   -62°→1.2067   -56°→1.2034   -51°→1.2008   -45°→1.1987   -34°→1.1954   -23°→1.1929   -11°→1.1904   +0°→1.1876   +11°→1.1843   +23°→1.1809   +34°→1.1779   +45°→1.1764★  +51°→1.1765
#   [APGD step  4100]  loss=1.3627  g_raw=4.027  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 040  train=1.3905  val=1.8507  acc=0.3852  |  avg_θ=-0.017  avg_γ=5.344  saddles=9/103
#   [APGD step  4200]  loss=1.3091  g_raw=5.887  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  4300]  loss=1.3173  g_raw=2.885  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  4400]  loss=1.5975  g_raw=9.399  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  4500]  loss=1.2246  g_raw=4.765  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  4600]  loss=1.3266  g_raw=6.284  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  4700]  loss=1.0936  g_raw=4.984  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  4800]  loss=1.3398  g_raw=6.128  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  4900]  loss=1.3176  g_raw=4.098  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  5000]  loss=1.3484  g_raw=4.263  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  5100]  loss=1.4354  g_raw=8.359  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 050  train=1.3240  val=1.5821  acc=0.4576  |  avg_θ=0.007  avg_γ=5.982  saddles=5/103
#   [APGD step  5200]  loss=1.3528  g_raw=4.143  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  5300]  loss=1.1961  g_raw=5.484  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  5400]  loss=1.1927  g_raw=4.841  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  5500]  loss=1.1688  g_raw=5.044  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  5600]  loss=1.2749  g_raw=4.913  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  5700]  loss=1.3701  g_raw=6.289  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  5800]  loss=1.2020  g_raw=4.890  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=-0.589rad  rho=0.01500  bt1= 2
#              phase scan: -84°→1.1462   -79°→1.1379   -73°→1.1310   -67°→1.1254   -62°→1.1211   -56°→1.1179   -51°→1.1157   -45°→1.1144   -34°→1.1136★  -23°→1.1142   -11°→1.1151   +0°→1.1156   +11°→1.1155   +23°→1.1150   +34°→1.1148   +45°→1.1158   +51°→1.1171
#   [APGD step  5900]  loss=1.4821  g_raw=7.509  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  6000]  loss=1.1303  g_raw=4.641  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  6100]  loss=1.3901  g_raw=8.109  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 060  train=1.2461  val=1.4222  acc=0.4831  |  avg_θ=-0.010  avg_γ=6.073  saddles=3/103
#   [APGD step  6200]  loss=1.1912  g_raw=7.423  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  6300]  loss=1.0958  g_raw=6.688  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  6400]  loss=1.1870  g_raw=6.837  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  6500]  loss=1.3095  g_raw=6.813  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  6600]  loss=1.0298  g_raw=4.614  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=-0.196rad  rho=0.01500  bt1= 2
#              phase scan: -84°→1.0679   -79°→1.0569   -73°→1.0467   -67°→1.0375   -62°→1.0295   -56°→1.0225   -51°→1.0166   -45°→1.0118   -34°→1.0052   -23°→1.0022   -11°→1.0022★  +0°→1.0045   +11°→1.0085   +23°→1.0140   +34°→1.0209   +45°→1.0294   +51°→1.0344
#   [APGD step  6700]  loss=1.0553  g_raw=4.638  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  6800]  loss=1.2962  g_raw=6.350  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  6900]  loss=1.1785  g_raw=5.113  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  7000]  loss=1.3687  g_raw=6.864  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  7100]  loss=1.1582  g_raw=4.950  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  7200]  loss=1.1853  g_raw=7.278  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 070  train=1.1738  val=1.4531  acc=0.5474  |  avg_θ=0.010  avg_γ=6.942  saddles=2/103
#   [APGD step  7300]  loss=0.9937  g_raw=5.330  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  7400]  loss=1.2079  g_raw=8.189  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  7500]  loss=1.1555  g_raw=6.876  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  7600]  loss=1.1033  g_raw=5.973  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  7700]  loss=1.1340  g_raw=6.648  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  7800]  loss=1.0865  g_raw=8.908  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  7900]  loss=0.9338  g_raw=4.544  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  8000]  loss=1.3092  g_raw=10.625  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  8100]  loss=1.0312  g_raw=7.956  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  8200]  loss=1.0551  g_raw=7.394  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 080  train=1.0618  val=1.3560  acc=0.5297  |  avg_θ=0.006  avg_γ=6.904  saddles=3/103
#   [APGD step  8300]  loss=0.9256  g_raw=6.834  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  8400]  loss=1.1837  g_raw=7.012  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  8500]  loss=1.0849  g_raw=7.326  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  8600]  loss=0.9117  g_raw=5.054  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  8700]  loss=0.8567  g_raw=6.492  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  8800]  loss=0.9043  g_raw=7.623  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  8900]  loss=0.8544  g_raw=7.937  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  9000]  loss=0.9067  g_raw=4.761  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  9100]  loss=0.8354  g_raw=5.801  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  9200]  loss=0.8449  g_raw=11.981  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 090  train=0.9812  val=1.8148  acc=0.4804  |  avg_θ=-0.002  avg_γ=8.210  saddles=1/103
#   [APGD step  9300]  loss=1.2387  g_raw=7.975  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  9400]  loss=0.9391  g_raw=6.807  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  9500]  loss=0.9786  g_raw=14.224  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  9600]  loss=0.8659  g_raw=6.166  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  9700]  loss=1.0327  g_raw=7.053  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  9800]  loss=0.9996  g_raw=7.280  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step  9900]  loss=1.1113  g_raw=10.713  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 10000]  loss=1.0061  g_raw=9.749  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 10100]  loss=0.8820  g_raw=7.410  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 10200]  loss=1.1588  g_raw=11.578  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 10300]  loss=0.5882  g_raw=8.213  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 100  train=0.8798  val=1.0424  acc=0.6572  |  avg_θ=-0.006  avg_γ=8.257  saddles=1/103
#   [APGD step 10400]  loss=0.9149  g_raw=7.370  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 10500]  loss=1.0294  g_raw=8.941  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 10600]  loss=0.8712  g_raw=10.339  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 10700]  loss=0.7334  g_raw=5.858  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 10800]  loss=0.7902  g_raw=9.188  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 10900]  loss=0.8240  g_raw=8.810  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 11000]  loss=0.7997  g_raw=9.392  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 11100]  loss=1.0089  g_raw=8.618  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 11200]  loss=0.7787  g_raw=6.652  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 11300]  loss=0.7745  g_raw=10.380  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 110  train=0.8112  val=0.8607  acc=0.7076  |  avg_θ=-0.008  avg_γ=9.036  saddles=1/103
#   [APGD step 11400]  loss=0.7369  g_raw=7.141  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 11500]  loss=0.4556  g_raw=4.292  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 11600]  loss=0.7313  g_raw=6.524  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 11700]  loss=0.6900  g_raw=8.901  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 11800]  loss=0.7085  g_raw=12.608  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 11900]  loss=0.8751  g_raw=9.839  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 12000]  loss=0.7107  g_raw=6.266  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 12100]  loss=0.7843  g_raw=8.429  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 12200]  loss=0.9694  g_raw=11.328  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 12300]  loss=0.8626  g_raw=8.468  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 120  train=0.7275  val=1.0415  acc=0.6687  |  avg_θ=0.000  avg_γ=9.386  saddles=0/103
#   [APGD step 12400]  loss=0.8342  g_raw=10.836  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 12500]  loss=0.6530  g_raw=8.264  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 12600]  loss=0.5763  g_raw=9.849  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 12700]  loss=0.6787  g_raw=9.553  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=+0.393rad  rho=0.03000  bt1= 1
#              phase scan: -84°→0.7429   -79°→0.7254   -73°→0.7091   -67°→0.6940   -62°→0.6801   -56°→0.6675   -51°→0.6561   -45°→0.6457   -34°→0.6279   -23°→0.6136   -11°→0.6020   +0°→0.5931   +11°→0.5867   +23°→0.5836★  +34°→0.5846   +45°→0.5910   +51°→0.5966
#   [APGD step 12800]  loss=0.6833  g_raw=6.128  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 12900]  loss=0.9252  g_raw=10.372  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 13000]  loss=0.8929  g_raw=13.446  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 13100]  loss=0.7247  g_raw=6.947  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 13200]  loss=0.6157  g_raw=9.072  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 13300]  loss=0.5818  g_raw=6.703  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 130  train=0.6446  val=0.8605  acc=0.7076  |  avg_θ=0.000  avg_γ=9.307  saddles=0/103
#   [APGD step 13400]  loss=0.6255  g_raw=10.257  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 13500]  loss=0.4755  g_raw=5.869  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 13600]  loss=0.5196  g_raw=8.105  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 13700]  loss=0.6862  g_raw=12.212  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 13800]  loss=0.5674  g_raw=5.710  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 13900]  loss=0.7680  g_raw=13.144  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 14000]  loss=0.5566  g_raw=6.653  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 14100]  loss=0.4668  g_raw=7.381  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 14200]  loss=0.6692  g_raw=9.322  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 14300]  loss=0.5495  g_raw=10.266  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 14400]  loss=0.6664  g_raw=9.512  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 140  train=0.5842  val=0.6821  acc=0.7558  |  avg_θ=0.000  avg_γ=9.166  saddles=0/103
#   [APGD step 14500]  loss=0.5175  g_raw=8.598  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 14600]  loss=0.5077  g_raw=5.527  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 14700]  loss=0.5958  g_raw=10.324  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 14800]  loss=0.3783  g_raw=6.092  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 14900]  loss=0.4321  g_raw=6.584  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 15000]  loss=0.5748  g_raw=9.195  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 15100]  loss=0.5042  g_raw=9.442  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 15200]  loss=0.5386  g_raw=12.285  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 15300]  loss=0.4125  g_raw=6.901  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 15400]  loss=0.4437  g_raw=8.387  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 150  train=0.5156  val=1.0310  acc=0.6541  |  avg_θ=-0.011  avg_γ=8.891  saddles=3/103
#   [APGD step 15500]  loss=0.4105  g_raw=6.208  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 15600]  loss=0.6572  g_raw=11.736  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 15700]  loss=0.5408  g_raw=9.747  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 15800]  loss=0.4351  g_raw=10.008  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 15900]  loss=0.5415  g_raw=9.507  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 16000]  loss=0.3663  g_raw=8.815  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 16100]  loss=0.2935  g_raw=4.954  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 16200]  loss=0.2340  g_raw=3.753  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 16300]  loss=0.5161  g_raw=9.027  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 16400]  loss=0.4780  g_raw=7.054  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 160  train=0.4605  val=0.8219  acc=0.7192  |  avg_θ=0.008  avg_γ=8.448  saddles=3/103
#   [APGD step 16500]  loss=0.4603  g_raw=9.074  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 16600]  loss=0.5095  g_raw=10.625  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 16700]  loss=0.3955  g_raw=7.247  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 16800]  loss=0.3955  g_raw=6.988  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 16900]  loss=0.6938  g_raw=13.066  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 17000]  loss=0.4120  g_raw=6.950  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 17100]  loss=0.3629  g_raw=9.828  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 17200]  loss=0.4973  g_raw=10.944  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 17300]  loss=0.5284  g_raw=9.468  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 17400]  loss=0.2819  g_raw=4.975  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 17500]  loss=0.4632  g_raw=8.057  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 170  train=0.4243  val=0.4971  acc=0.8347  |  avg_θ=0.002  avg_γ=8.328  saddles=4/103
#   [APGD step 17600]  loss=0.4726  g_raw=12.200  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 17700]  loss=0.3385  g_raw=6.093  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 17800]  loss=0.4278  g_raw=7.951  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 17900]  loss=0.4327  g_raw=9.602  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 18000]  loss=0.4516  g_raw=7.421  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 18100]  loss=0.3767  g_raw=8.070  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=-0.589rad  rho=0.01500  bt1= 2
#              phase scan: -84°→0.3237   -79°→0.3169   -73°→0.3114   -67°→0.3070   -62°→0.3035   -56°→0.3010   -51°→0.2992   -45°→0.2980   -34°→0.2973★  -23°→0.2978   -11°→0.2989   +0°→0.3000   +11°→0.3011   +23°→0.3022   +34°→0.3044   +45°→0.3083   +51°→0.3112
#   [APGD step 18200]  loss=0.2868  g_raw=6.198  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 18300]  loss=0.3739  g_raw=8.318  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 18400]  loss=0.6241  g_raw=14.242  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 18500]  loss=0.3832  g_raw=9.266  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 180  train=0.3932  val=0.4632  acc=0.8413  |  avg_θ=-0.005  avg_γ=8.492  saddles=2/103
#   [APGD step 18600]  loss=0.4683  g_raw=9.871  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 18700]  loss=0.3498  g_raw=7.943  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 18800]  loss=0.3595  g_raw=5.976  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 18900]  loss=0.4664  g_raw=13.006  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 19000]  loss=0.3696  g_raw=10.401  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 19100]  loss=0.2882  g_raw=5.096  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 19200]  loss=0.3257  g_raw=7.098  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 19300]  loss=0.2804  g_raw=6.453  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 19400]  loss=0.3791  g_raw=9.025  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 19500]  loss=0.2255  g_raw=4.936  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=-0.393rad  rho=0.03000  bt1= 1
#              phase scan: -84°→0.2129   -79°→0.2042   -73°→0.1967   -67°→0.1904   -62°→0.1852   -56°→0.1809   -51°→0.1776   -45°→0.1750   -34°→0.1722   -23°→0.1717★  -11°→0.1728   +0°→0.1746   +11°→0.1767   +23°→0.1789   +34°→0.1810   +45°→0.1833   +51°→0.1846
#   Ep 190  train=0.3539  val=0.6432  acc=0.7650  |  avg_θ=0.008  avg_γ=8.178  saddles=3/103
#   [APGD step 19600]  loss=0.4784  g_raw=9.464  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 19700]  loss=0.4247  g_raw=12.251  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 19800]  loss=0.3686  g_raw=6.972  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 19900]  loss=0.4249  g_raw=7.707  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 20000]  loss=0.3501  g_raw=7.425  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 20100]  loss=0.3005  g_raw=6.192  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 20200]  loss=0.3996  g_raw=7.695  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 20300]  loss=0.3212  g_raw=8.099  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 20400]  loss=0.1865  g_raw=4.598  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 20500]  loss=0.3253  g_raw=7.451  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 20600]  loss=0.4063  g_raw=11.769  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 200  train=0.3247  val=0.3492  acc=0.8775  |  avg_θ=0.017  avg_γ=7.688  saddles=4/103
#   [APGD step 20700]  loss=0.2653  g_raw=8.830  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 20800]  loss=0.2999  g_raw=6.132  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 20900]  loss=0.4171  g_raw=8.417  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 21000]  loss=0.2783  g_raw=5.685  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 21100]  loss=0.3314  g_raw=7.022  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 21200]  loss=0.3256  g_raw=10.322  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 21300]  loss=0.3774  g_raw=7.098  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 21400]  loss=0.2610  g_raw=8.031  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 21500]  loss=0.2050  g_raw=5.568  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 21600]  loss=0.3116  g_raw=5.622  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 210  train=0.3000  val=0.4886  acc=0.8139  |  avg_θ=-0.011  avg_γ=7.657  saddles=2/103
#   [APGD step 21700]  loss=0.5470  g_raw=14.242  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 21800]  loss=0.2681  g_raw=8.250  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 21900]  loss=0.3012  g_raw=10.707  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 22000]  loss=0.3962  g_raw=8.528  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 22100]  loss=0.2423  g_raw=5.278  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 22200]  loss=0.2757  g_raw=6.326  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 22300]  loss=0.2707  g_raw=7.454  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 22400]  loss=0.3821  g_raw=12.147  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 22500]  loss=0.4776  g_raw=16.611  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 22600]  loss=0.2784  g_raw=5.941  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 220  train=0.2708  val=0.5305  acc=0.8174  |  avg_θ=-0.017  avg_γ=7.299  saddles=4/103
#   [APGD step 22700]  loss=0.2920  g_raw=7.451  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 22800]  loss=0.1521  g_raw=4.042  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 22900]  loss=0.1592  g_raw=4.666  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 23000]  loss=0.1726  g_raw=4.163  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 23100]  loss=0.3575  g_raw=8.809  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 23200]  loss=0.2785  g_raw=5.691  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 23300]  loss=0.1899  g_raw=5.668  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 23400]  loss=0.3999  g_raw=11.651  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 23500]  loss=0.2592  g_raw=5.858  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 23600]  loss=0.2020  g_raw=6.737  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 230  train=0.2558  val=0.4415  acc=0.8367  |  avg_θ=0.002  avg_γ=7.109  saddles=3/103
#   [APGD step 23700]  loss=0.3813  g_raw=6.852  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 23800]  loss=0.2984  g_raw=8.824  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 23900]  loss=0.1900  g_raw=4.445  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 24000]  loss=0.1434  g_raw=4.483  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 24100]  loss=0.6635  g_raw=12.846  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 24200]  loss=0.2130  g_raw=4.900  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 24300]  loss=0.2591  g_raw=5.437  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 24400]  loss=0.5495  g_raw=11.751  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 24500]  loss=0.1962  g_raw=7.532  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 24600]  loss=0.2714  g_raw=5.375  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 24700]  loss=0.2414  g_raw=5.810  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 240  train=0.2361  val=0.3456  acc=0.8659  |  avg_θ=-0.010  avg_γ=6.757  saddles=3/103
#   [APGD step 24800]  loss=0.1930  g_raw=5.488  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 24900]  loss=0.2591  g_raw=6.139  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 25000]  loss=0.2358  g_raw=5.847  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 25100]  loss=0.2515  g_raw=8.384  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 25200]  loss=0.2018  g_raw=7.670  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 25300]  loss=0.1546  g_raw=4.591  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 25400]  loss=0.4108  g_raw=14.802  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 25500]  loss=0.2365  g_raw=5.638  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 25600]  loss=0.1564  g_raw=4.719  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 25700]  loss=0.3716  g_raw=9.375  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 250  train=0.2213  val=0.3983  acc=0.8490  |  avg_θ=-0.015  avg_γ=6.976  saddles=5/103
#   [APGD step 25800]  loss=0.2702  g_raw=8.377  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 25900]  loss=0.2727  g_raw=8.076  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 26000]  loss=0.2388  g_raw=6.332  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 26100]  loss=0.0754  g_raw=2.625  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 26200]  loss=0.2762  g_raw=7.068  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 26300]  loss=0.1471  g_raw=5.396  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 26400]  loss=0.0961  g_raw=3.039  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 26500]  loss=0.1623  g_raw=6.306  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 26600]  loss=0.1919  g_raw=5.825  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 26700]  loss=0.1639  g_raw=6.869  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 260  train=0.1947  val=0.7084  acc=0.7858  |  avg_θ=-0.016  avg_γ=6.240  saddles=7/103
#   [APGD step 26800]  loss=0.2142  g_raw=6.264  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 26900]  loss=0.2183  g_raw=6.906  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 27000]  loss=0.1853  g_raw=6.847  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 27100]  loss=0.2484  g_raw=4.926  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 27200]  loss=0.3428  g_raw=12.473  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 27300]  loss=0.1556  g_raw=5.220  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 27400]  loss=0.1735  g_raw=5.120  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 27500]  loss=0.1412  g_raw=4.477  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 27600]  loss=0.0709  g_raw=3.686  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 27700]  loss=0.1203  g_raw=3.543  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 27800]  loss=0.2011  g_raw=5.658  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 270  train=0.1932  val=0.2443  acc=0.9160  |  avg_θ=0.011  avg_γ=6.481  saddles=4/103
#   [APGD step 27900]  loss=0.1579  g_raw=6.858  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 28000]  loss=0.1135  g_raw=2.715  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=-0.981rad  rho=0.03000  bt1= 1
#              phase scan: -84°→0.0787   -79°→0.0762   -73°→0.0742   -67°→0.0729   -62°→0.0721   -56°→0.0719★  -51°→0.0721   -45°→0.0727   -34°→0.0746   -23°→0.0769   -11°→0.0788   +0°→0.0800   +11°→0.0801   +23°→0.0793   +34°→0.0779   +45°→0.0766   +51°→0.0763
#   [APGD step 28100]  loss=0.1056  g_raw=3.287  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 28200]  loss=0.1006  g_raw=3.634  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 28300]  loss=0.2636  g_raw=7.352  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 28400]  loss=0.2929  g_raw=6.398  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 28500]  loss=0.1346  g_raw=5.364  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 28600]  loss=0.1439  g_raw=4.856  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 28700]  loss=0.1572  g_raw=5.086  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 28800]  loss=0.1217  g_raw=4.572  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 280  train=0.1676  val=0.6832  acc=0.7951  |  avg_θ=-0.018  avg_γ=6.055  saddles=7/103
#   [APGD step 28900]  loss=0.1478  g_raw=6.070  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 29000]  loss=0.1020  g_raw=3.373  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 29100]  loss=0.1120  g_raw=4.342  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 29200]  loss=0.1032  g_raw=3.831  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 29300]  loss=0.0570  g_raw=2.535  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 29400]  loss=0.1585  g_raw=5.887  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 29500]  loss=0.1931  g_raw=5.228  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 29600]  loss=0.1797  g_raw=5.170  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 29700]  loss=0.1322  g_raw=5.005  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=-0.883rad  rho=0.03000  bt1= 1
#              phase scan: -84°→0.0407   -79°→0.0361   -73°→0.0326   -67°→0.0301   -62°→0.0286   -56°→0.0278   -51°→0.0277★  -45°→0.0282   -34°→0.0306   -23°→0.0343   -11°→0.0385   +0°→0.0426   +11°→0.0457   +23°→0.0474   +34°→0.0474   +45°→0.0456   +51°→0.0443
#   [APGD step 29800]  loss=0.1508  g_raw=5.452  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 290  train=0.1591  val=0.3291  acc=0.8910  |  avg_θ=-0.041  avg_γ=6.129  saddles=6/103
#   [APGD step 29900]  loss=0.1553  g_raw=4.617  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 30000]  loss=0.2294  g_raw=5.650  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 30100]  loss=0.1336  g_raw=5.968  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 30200]  loss=0.1539  g_raw=4.761  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 30300]  loss=0.1195  g_raw=3.054  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 30400]  loss=0.2308  g_raw=6.932  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 30500]  loss=0.2175  g_raw=6.481  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 30600]  loss=0.0708  g_raw=3.504  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 30700]  loss=0.2401  g_raw=11.573  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 30800]  loss=0.1516  g_raw=7.695  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 30900]  loss=0.0423  g_raw=3.722  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=-0.196rad  rho=0.01500  bt1= 2
#              phase scan: -84°→0.0702   -79°→0.0601   -73°→0.0513   -67°→0.0438   -62°→0.0375   -56°→0.0325   -51°→0.0286   -45°→0.0257   -34°→0.0222   -23°→0.0209   -11°→0.0209★  +0°→0.0214   +11°→0.0219   +23°→0.0223   +34°→0.0227   +45°→0.0240   +51°→0.0253
#   Ep 300  train=0.1416  val=0.4283  acc=0.8617  |  avg_θ=0.020  avg_γ=5.665  saddles=14/103
#   [APGD step 31000]  loss=0.1513  g_raw=5.412  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 31100]  loss=0.1133  g_raw=6.812  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 31200]  loss=0.3084  g_raw=8.314  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 31300]  loss=0.0785  g_raw=3.611  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 31400]  loss=0.1425  g_raw=6.977  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 31500]  loss=0.1471  g_raw=5.514  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 31600]  loss=0.1078  g_raw=4.014  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 31700]  loss=0.1167  g_raw=3.458  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 31800]  loss=0.0722  g_raw=3.140  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 31900]  loss=0.1043  g_raw=4.350  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 310  train=0.1336  val=0.2193  acc=0.9284  |  avg_θ=0.010  avg_γ=5.332  saddles=6/103
#   [APGD step 32000]  loss=0.2240  g_raw=7.741  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 32100]  loss=0.1011  g_raw=5.437  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 32200]  loss=0.0997  g_raw=5.154  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 32300]  loss=0.1265  g_raw=4.520  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 32400]  loss=0.1276  g_raw=4.625  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 32500]  loss=0.0932  g_raw=4.380  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 32600]  loss=0.0824  g_raw=3.364  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 32700]  loss=0.1162  g_raw=4.265  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 32800]  loss=0.0582  g_raw=2.937  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 32900]  loss=0.0361  g_raw=1.285  g_clip=1.285  bt0= 2  regime=SADDLE  θ*=-0.981rad  rho=0.03000  bt1= 1
#              phase scan: -84°→0.0229   -79°→0.0224   -73°→0.0220   -67°→0.0217   -62°→0.0216   -56°→0.0216★  -51°→0.0216   -45°→0.0218   -34°→0.0222   -23°→0.0227   -11°→0.0232   +0°→0.0236   +11°→0.0238   +23°→0.0238   +34°→0.0237   +45°→0.0235   +51°→0.0235
#   Ep 320  train=0.1229  val=0.3663  acc=0.8817  |  avg_θ=-0.011  avg_γ=4.749  saddles=8/103
#   [APGD step 33000]  loss=0.2135  g_raw=6.777  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 33100]  loss=0.0881  g_raw=3.600  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 33200]  loss=0.1502  g_raw=5.837  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 33300]  loss=0.0584  g_raw=2.820  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=+0.785rad  rho=0.03000  bt1= 1
#              phase scan: -84°→0.0387   -79°→0.0358   -73°→0.0336   -67°→0.0320   -62°→0.0309   -56°→0.0302   -51°→0.0299   -45°→0.0297   -34°→0.0296   -23°→0.0296   -11°→0.0293   +0°→0.0284   +11°→0.0271   +23°→0.0257   +34°→0.0248   +45°→0.0247★  +51°→0.0252
#   [APGD step 33400]  loss=0.0712  g_raw=2.522  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 33500]  loss=0.0946  g_raw=3.212  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 33600]  loss=0.0366  g_raw=1.523  g_clip=1.523  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 33700]  loss=0.0851  g_raw=3.260  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=-0.196rad  rho=0.01500  bt1= 2
#              phase scan: -84°→0.0648   -79°→0.0604   -73°→0.0565   -67°→0.0532   -62°→0.0505   -56°→0.0482   -51°→0.0464   -45°→0.0450   -34°→0.0430   -23°→0.0419   -11°→0.0415★  +0°→0.0415   +11°→0.0418   +23°→0.0421   +34°→0.0426   +45°→0.0432   +51°→0.0438
#   [APGD step 33800]  loss=0.1027  g_raw=5.582  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 33900]  loss=0.0527  g_raw=2.483  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=+0.883rad  rho=0.03000  bt1= 1
#              phase scan: -84°→0.0392   -79°→0.0378   -73°→0.0368   -67°→0.0361   -62°→0.0357   -56°→0.0356   -51°→0.0356   -45°→0.0358   -34°→0.0364   -23°→0.0371   -11°→0.0377   +0°→0.0378   +11°→0.0374   +23°→0.0366   +34°→0.0357   +45°→0.0349   +51°→0.0347★
#   Ep 330  train=0.1204  val=0.4890  acc=0.8548  |  avg_θ=-0.005  avg_γ=4.984  saddles=7/103
#   [APGD step 34000]  loss=0.1040  g_raw=3.441  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 34100]  loss=0.1359  g_raw=4.305  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 34200]  loss=0.0925  g_raw=5.134  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 34300]  loss=0.2120  g_raw=16.232  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 34400]  loss=0.1366  g_raw=4.729  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 34500]  loss=0.0717  g_raw=3.423  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 34600]  loss=0.0817  g_raw=4.746  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 34700]  loss=0.1331  g_raw=4.214  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 34800]  loss=0.1318  g_raw=5.985  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 34900]  loss=0.0585  g_raw=2.961  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 35000]  loss=0.0707  g_raw=3.092  g_clip=2.000  bt0= 2  regime=SADDLE  θ*=+0.883rad  rho=0.03000  bt1= 1
#              phase scan: -84°→0.0491   -79°→0.0485   -73°→0.0482   -67°→0.0483   -62°→0.0486   -56°→0.0490   -51°→0.0494   -45°→0.0498   -34°→0.0504   -23°→0.0505   -11°→0.0499   +0°→0.0486   +11°→0.0467   +23°→0.0446   +34°→0.0425   +45°→0.0408   +51°→0.0403★
#   Ep 340  train=0.1013  val=0.5646  acc=0.8448  |  avg_θ=-0.050  avg_γ=4.804  saddles=15/103
#   [APGD step 35100]  loss=0.0604  g_raw=3.222  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 35200]  loss=0.0998  g_raw=4.651  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 35300]  loss=0.0977  g_raw=3.458  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 35400]  loss=0.3310  g_raw=12.020  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 35500]  loss=0.0931  g_raw=5.534  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 35600]  loss=0.0849  g_raw=5.057  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 35700]  loss=0.2175  g_raw=6.441  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 35800]  loss=0.0970  g_raw=6.292  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 35900]  loss=0.0535  g_raw=3.095  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   [APGD step 36000]  loss=0.1355  g_raw=6.604  g_clip=2.000  bt0= 1  regime=normal  θ*=+0.000rad  rho=0.03000  bt1= 1
#   Ep 350  train=0.1037  val=0.5251  acc=0.8448  |  avg_θ=0.008  avg_γ=4.895  saddles=14/103
# APGD-SGD done.
# 22547

# %%
# Load best checkpoint before evaluating APGD
ckpt_a = torch.load(os.path.join(CKPT_DIR, "apgd_sgd_best.pt"), map_location=DEVICE)
model_a.load_state_dict(ckpt_a['model_state_dict'])
print(f"APGD best: ep{ckpt_a['epoch']}  val_acc={ckpt_a['val_acc']:.4f}")
results_apgd = evaluate_full(model_a, val_loader, criterion, CLASS_NAMES)


# ── APGD-SGD — test evaluation ─────────────────────────────────────────────────
results_apgd = evaluate_full(model_a, val_loader, criterion, CLASS_NAMES)
print_test_report(results_apgd, "APGD-SGD")
plot_confusion_matrix(results_apgd, "APGD-SGD",
                      SAVE_DIR, "SGD_apgd_confusion.png")
# Out:
# APGD best: ep329  val_acc=0.9441
#
# ══════════════════════════════════════════════════════════════
#   TEST REPORT — APGD-SGD
# ══════════════════════════════════════════════════════════════
#   Overall accuracy : 94.41%
#   Test loss        : 0.1721
#
#   Per-class accuracy:
#   Class                     Acc       N
#   ────────────────────────────────────────
#   bmp2_tank              92.33%     587  ██████████████████
#   btr70_transport        92.86%     196  ██████████████████
#   t72_tank               97.94%     583  ███████████████████
#   d7_bulldozer           99.17%     121  ███████████████████
#   t62_tank               98.40%     125  ███████████████████
#   zil131_truck           93.91%     115  ██████████████████
#   btr60_transport        59.34%      91  ███████████
#   zsu23-4_gun            98.19%     277  ███████████████████
#   brdm2_truck            97.10%     276  ███████████████████
#   2s1_gun                93.78%     225  ██████████████████
#
#   Classification report:
#                  precision    recall  f1-score   support
#
#       bmp2_tank     0.9377    0.9233    0.9305       587
# btr70_transport     0.9192    0.9286    0.9239       196
#        t72_tank     0.9376    0.9794    0.9581       583
#    d7_bulldozer     0.9449    0.9917    0.9677       121
#        t62_tank     0.9919    0.9840    0.9880       125
#    zil131_truck     0.9908    0.9391    0.9643       115
# btr60_transport     0.6279    0.5934    0.6102        91
#     zsu23-4_gun     0.9891    0.9819    0.9855       277
#     brdm2_truck     0.9963    0.9710    0.9835       276
#         2s1_gun     0.9548    0.9378    0.9462       225
#
#        accuracy                         0.9441      2596
#       macro avg     0.9290    0.9230    0.9258      2596
#    weighted avg     0.9439    0.9441    0.9438      2596
# Saved → /kaggle/working/plots/sgd/SGD_apgd_confusion.png

# %%
plot_static_vs_apgd(hist_s, hist_a, "SGD", SAVE_DIR)
summary_table(hist_s, hist_a, "SGD")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_55/767432543.py in <cell line: 0>()
# ----> 1 plot_static_vs_apgd(hist_s, hist_a, "SGD", SAVE_DIR)
#       2 summary_table(hist_s, hist_a, "SGD")
#
# /tmp/ipykernel_55/2560274581.py in plot_static_vs_apgd(static_hist, apgd_hist, title, save_dir)
#      15     # ── [0] Validation loss ──────────────────────────────────────────────────
#      16     axes[0].plot(ep, static_hist['val_loss'], label='Static θ=0', lw=2, color='steelblue')
# ---> 17     axes[0].plot(ep, apgd_hist['val_loss'],   label='APGD',       lw=2, color='darkorange', ls='--')
#      18     axes[0].set_title('Validation Loss'); axes[0].set_xlabel('Epoch')
#      19     axes[0].legend(); axes[0].grid(True, alpha=0.3)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778         for line in lines:
#    1779             self.add_line(line)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in __call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295                 this += args[0],
#     296                 args = args[1:]
# --> 297             yield from self._plot_args(
#     298                 axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299                 return_kwargs=return_kwargs
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in _plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     492
#     493         if x.shape[0] != y.shape[0]:
# --> 494             raise ValueError(f"x and y must have same first dimension, but "
#     495                              f"have shapes {x.shape} and {y.shape}")
#     496         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (300,) and (350,)

# %%
# ── Head-to-head per-class bar chart ───────────────────────────────────────────
plot_per_class_bar(results_static, results_apgd, SAVE_DIR)

# Delta table
print(f"\n{'─'*58}")
print(f"  Per-class Δ accuracy  (APGD − Static)")
print(f"{'─'*58}")
print(f"  {'Class':<20} {'Static':>8}  {'APGD':>8}  {'Δ':>8}")
print(f"  {'─'*54}")
for name, a_s, a_a in zip(
        CLASS_NAMES,
        results_static['per_class_acc'],
        results_apgd['per_class_acc']):
    delta = a_a - a_s
    arrow = '▲' if delta > 0.005 else ('▼' if delta < -0.005 else ' ')
    print(f"  {name:<20} {a_s*100:>7.2f}%  {a_a*100:>7.2f}%  {delta*100:>+7.2f}%  {arrow}")

# %%
# ── Save results for cross-optimizer comparison (notebook 05) ─────────────────
torch.save(
    {'static': hist_s, 'apgd': hist_a,
     'results_static': results_static, 'results_apgd': results_apgd},
    os.path.join(SAVE_DIR, "sgd_results.pt")
)
print(f"Results saved → {SAVE_DIR}/sgd_results.pt")
